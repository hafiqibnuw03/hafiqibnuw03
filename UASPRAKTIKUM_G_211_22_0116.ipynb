# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a076d40f-8ad8-4bba-ae6d-227bd399d43b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a076d40f-8ad8-4bba-ae6d-227bd399d43b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded
# Out:
# {'stock.csv': b'Stock Name,Symbol,Shares,Purchase Price,Cost Basis,Current Price,Market Value,Gain/Loss,Dividend/Share,Annual Yield \nApple,AAPL,100,$90.00,"$9,000.00",$144.13,"$14,413.27","$14,269.14",$2.28,1.58%\nMicrosoft,MSFT,200,$32.00,"$6,400.00",$65.57,"$13,114.14","$13,048.57",$1.56,2.38%\nSalesforce,CRM,150,$25.00,"$3,750.00",$82.57,"$12,385.50","$12,302.93",$0.00,0.00%\nOracle,ORCL,250,$50.00,"$12,500.00",$44.56,"$11,138.75","$11,094.20",$0.64,1.44%\nHewlett Packard Enterprise,HPE,500,$18.00,"$9,000.00",$17.69,"$8,842.50","$8,824.82",$0.26,1.47%\nAlphabet,GOOG,100,$225.00,"$22,500.00",$833.36,"$83,336.00","$82,502.64",$0.00,0.00%\nIntel,INTC,200,$22.00,"$4,400.00",$36.07,"$7,213.00","$7,176.94",$1.09,3.02%\nCisco,CSCO,225,$18.00,"$4,050.00",$33.24,"$7,478.78","$7,445.54",$1.16,3.49%\nQualcomm,QCOM,185,$65.00,"$12,025.00",$56.48,"$10,447.88","$10,391.40",$2.12,3.75%\nAmazon,AMZN,50,$800.00,"$40,000.00",$897.64,"$44,882.00","$43,984.36",$0.00,0.00%\nRedhat,RHT,100,$95.00,"$9,
# ...

# %%
# load the csv
data1 = pd.read_csv("stock.csv")
data1
# Out:
#                     Stock Name Symbol  Shares Purchase Price  Cost Basis  \
# 0                        Apple   AAPL     100         $90.00   $9,000.00
# 1                    Microsoft   MSFT     200         $32.00   $6,400.00
# 2                   Salesforce    CRM     150         $25.00   $3,750.00
# 3                       Oracle   ORCL     250         $50.00  $12,500.00
# 4   Hewlett Packard Enterprise    HPE     500         $18.00   $9,000.00
# 5                     Alphabet   GOOG     100        $225.00  $22,500.00
# 6                        Intel   INTC     200         $22.00   $4,400.00
# 7                        Cisco   CSCO     225         $18.00   $4,050.00
# 8                     Qualcomm   QCOM     185         $65.00  $12,025.00
# 9                       Amazon   AMZN      50        $800.00  $40,000.00
# 10                      Redhat    RHT     100         $95.00   $9,500.00
# 11                    Facebook     FB    1000         $17.00  $17,000.00
# ...

# %% [markdown]
# 1. a) Histogram

# %%
plt.figure(figsize=(10,27))


plt.subplot(3,1,1)
plt.title('histogram Purchase Price')
plt.hist(data1['Purchase Price'], color='b')
plt.xlabel('Purchase Price', fontsize=8)
plt.ylabel('Frekuensi', fontsize=8)
plt.xticks(rotation='vertical')

plt.subplot(3,1,2)
plt.title('histogram Current Price')
plt.hist(data1['Current Price'], color='r')
plt.xlabel('Current Price', fontsize=8)
plt.ylabel('Frekuensi', fontsize=8)
plt.xticks(rotation='vertical')

plt.subplot(3,1,3)
plt.title('histogram Gain/Loss')
plt.hist(data1['Gain/Loss'], color='c')
plt.xlabel('Gain/Loss', fontsize=8)
plt.ylabel('Frekuensi', fontsize=8)
plt.xticks(rotation='vertical')

plt.show()

# %% [markdown]
# 1.b) Atribut Stock Name dan Symbol yang memiliki Dividen / Share 5 tertinggi

# %%
database2 = df.sort_values(by='Dividend/Share', ascending=False)
dividend = database2.head(5)
print(dividend[['Stock Name', 'Symbol', 'Dividend/Share']])
# Out:
#   Stock Name Symbol Dividend/Share
# 0      Apple   AAPL          $2.28
# 8   Qualcomm   QCOM          $2.12
# 1  Microsoft   MSFT          $1.56
# 7      Cisco   CSCO          $1.16
# 6      Intel   INTC          $1.09

# %% [markdown]
# 1. C)Atribut Stock Name dan Symbol yang memiliki Market Value 5 tertinggi

# %%
database2 = data1.sort_values(by='Market Value', ascending=False)
MarketValue= database2.head(5)
print(MarketValue[['Stock Name', 'Symbol', 'Market Value']])
# Out:
#                     Stock Name Symbol Market Value
# 5                     Alphabet   GOOG   $83,336.00
# 4   Hewlett Packard Enterprise    HPE    $8,842.50
# 10                      Redhat    RHT    $8,626.00
# 7                        Cisco   CSCO    $7,478.78
# 12                     Twitter   TWTR    $7,302.55

# %% [markdown]
# 1.D) Atribut Stock Name dan Symbol yang memiliki Annual Yield 7 tertinggi

# %%
database2 = data1.sort_values(by='Annual Yield ', ascending=False)
AnnualYield= database2.head(5)
print(AnnualYield[['Stock Name', 'Symbol', 'Annual Yield ']])
# Out:
#   Stock Name Symbol Annual Yield
# 8   Qualcomm   QCOM         3.75%
# 7      Cisco   CSCO         3.49%
# 6      Intel   INTC         3.02%
# 1  Microsoft   MSFT         2.38%
# 0      Apple   AAPL         1.58%
